# %% [markdown]
# ## 1 Essential Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# # Load datasets
# from sklearn.datasets import load_iris
# iris = load_iris()
# df = pd.DataFrame(iris.data, columns=iris.feature_names)
# df['target'] = iris.target
# df.head()

# %%
# # Do lambda functions on columns
# df['Flower_name'] = df.target.apply(lambda x : iris.target_names[x])
# df['Spam'] = df['Category'].apply(lambda x : 1 if x=='spam' else 0)
# df.head()

# %%
## Discribe data set methods
#dir(digits)
#df.groupby('Category').describe()

# %%
## Check the shape of dataset
#df.shape

# %%
# df0 = df[df.target==0]
# df1 = df[df.target==1]
# df2 = df[df.target==2]

# %%
# # Display images of dataset
# %matplotlib inline
# plt.gray()
# plt.matshow(digits.images[0])

# %% [markdown]
# ## 2 Plot Charts

# %%
# import matplotlib.pyplot as plt

# # Set the figure size
# plt.figure(figsize=(10, 6))  # Adjust (width, height) as needed

# # Create your scatter plot
# plt.scatter(df.age, df['bought_insurance'], marker='*', color='blue')

# # Optionally add labels and title
# plt.xlabel('Age')
# plt.ylabel('Bought Insurance')
# plt.title('Age vs Bought Insurance')

# # Display the plot
# plt.show()

# %% [markdown]
# ## 3 Data preprocessing

# %% [markdown]
# ### 3.1 Handling Null Values

# %%
# Replace null values with median
# df.bedrooms = df.bedrooms.fillna(math.floor(df.bedrooms.median()))

# %% [markdown]
# ### 3.2 Data set operations

# %%
# df1 = df[df.cluster == 0]

# %% [markdown]
# ### 3.3 Scaling Data

# %%
from sklearn.preprocessing import MinMaxScaler
scaler  = MinMaxScaler()

# %%
df['Age'] = scaler.fit_transform(df[['Age']])

# %% [markdown]
# ### 3.4 Categorical columns

# %%
from PIL import Image
from IPython.display import display

# Load the image
image = Image.open('/Users/chandimajayamina/Screen records/Screenshot 2024-08-17 at 18.46.15.png')

# Resize the image to make it smaller
image_resized = image.resize((800, 300))  # Adjust (width, height) as needed

# Display the resized image
display(image_resized)
# Out:
# <PIL.Image.Image image mode=RGBA size=800x300>

# %% [markdown]
# ### For nominal categorical data we use one hot encoding

# %%
from PIL import Image
from IPython.display import display

# Load the image
image = Image.open('/Users/chandimajayamina/Screen records/Screenshot 2024-08-20 at 10.38.24.png')

# Resize the image to make it smaller
image_resized = image.resize((800, 300))  # Adjust (width, height) as needed

# Display the resized image
display(image_resized)
# Out:
# <PIL.Image.Image image mode=RGBA size=800x300>

# %%
df = pd.read_csv('./datafiles/homeprices_town.csv')
dummies = pd.get_dummies(df.town)
df_preprocessed_manual = pd.concat([df,dummies], axis='columns')
# We need to drop the main column and one dumy column to get out of dummy variable trap
df_preprocessed_manual = df_preprocessed_manual.drop(['town','west windsor'], axis='columns')
df_preprocessed_manual.head()
# Out:
#    area   price  monroe township  robinsville
# 0  2600  550000                1            0
# 1  3000  565000                1            0
# 2  3200  610000                1            0
# 3  3600  680000                1            0
# 4  4000  725000                1            0

# %%
df = pd.read_csv('./datafiles/homeprices_town.csv')
dummies = pd.get_dummies(df.town)
dummies.head()
# Out:
#    monroe township  robinsville  west windsor
# 0                1            0             0
# 1                1            0             0
# 2                1            0             0
# 3                1            0             0
# 4                1            0             0

# %% [markdown]
# ### Using sklearn onehot encoding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
dfle = df
dfle.town = le.fit_transform(dfle.town)
dfle.head()
# Out:
#    town  area   price
# 0     0  2600  550000
# 1     0  3000  565000
# 2     0  3200  610000
# 3     0  3600  680000
# 4     0  4000  725000

# %%
x = dfle[['town','area']].values
y = dfle.price

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
column_transformer = ColumnTransformer(
    transformers=[
        ('encoder', OneHotEncoder(drop='first'), [0])  # Specify the column(s) to be one-hot encoded
    ],
    remainder='passthrough'  # Leave the other columns unchanged
)
x = column_transformer.fit_transform(x)
x
# Out:
# array([[0.0e+00, 0.0e+00, 2.6e+03],
#        [0.0e+00, 0.0e+00, 3.0e+03],
#        [0.0e+00, 0.0e+00, 3.2e+03],
#        [0.0e+00, 0.0e+00, 3.6e+03],
#        [0.0e+00, 0.0e+00, 4.0e+03],
#        [0.0e+00, 1.0e+00, 2.6e+03],
#        [0.0e+00, 1.0e+00, 2.8e+03],
#        [0.0e+00, 1.0e+00, 3.3e+03],
#        [0.0e+00, 1.0e+00, 3.6e+03],
#        [1.0e+00, 0.0e+00, 2.6e+03],
#        [1.0e+00, 0.0e+00, 2.9e+03],
#        [1.0e+00, 0.0e+00, 3.1e+03],
#        [1.0e+00, 0.0e+00, 3.6e+03]])

# %% [markdown]
# ## 3.5 How to work with text message data | Count vectorization

# %% [markdown]
# ![Screenshot 2024-09-13 at 07.03.03.png](attachment:431b92ba-6b69-4e94-9479-33e9acb5ebc0.png)

# %% [markdown]
# ## 4 Cost Functions and Gradient Descent

# %%
# Mean squared error

# %%
from PIL import Image
from IPython.display import display

# Load the image
image = Image.open('/Users/chandimajayamina/Screen records/Screenshot 2024-08-16 at 21.39.54.png')

# Resize the image to make it smaller
image_resized = image.resize((800, 300))  # Adjust (width, height) as needed

# Display the resized image
display(image_resized)
# Out:
# <PIL.Image.Image image mode=RGBA size=800x300>

# %% [markdown]
# # *Cross Validation for What Model to Use

# %% [markdown]
# ### Method 1 K-Fold Cross Validation

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 5 Split data for ML model to train and test

# %%
df = pd.read_csv('./datafiles/carprices.csv')
import matplotlib.pyplot as plt
# %matplotlib inline
plt.scatter(df.Mileage, df['Sell Price($)'])

# %%
df.head()
# Out:
#    Mileage  Age(yrs)  Sell Price($)
# 0    69000         6          18000
# 1    35000         3          34000
# 2    57000         5          26100
# 3    22500         2          40000
# 4    46000         4          31500

# %%
x = df[['Mileage', 'Age(yrs)']]
y = df[['Sell Price($)']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %% [markdown]
# ## 6 Model Training

# %%
from sklearn import linear_model
reg = linear_model.LinearRegression()
reg.fit(x,y)
# Out:
# LinearRegression()

# %%
reg.predict([[0,0,2600]])
# Out:
# array([539709.7398409])

# %% [markdown]
# ## 7 Model Evaluation

# %%
## This check accuracy with test set
# model.score(x_test,y_test)

# %% [markdown]
# ### 7.1 Use confusion matrix

# %%
# from sklearn.metrics import confusion_matrix
# cm = confusion_matrix(y_test, y_pred)
# import seaborn as sns
# plt.figure(figsize=(10,7))
# sns.heatmap(cm, annot=True)
# plt.xlabel('Predicted')
# plt.ylabel('Truth')

# %% [markdown]
# ## 8 Pipeline Creation

# %%
from sklearn.pipeline import Pipeline
pipe = Pipeline([
    ('Vectorizer', CountVectorizer()), 
    ('Model', BernoulliNB())
])

# %%
pipe.fit(X_train, y_train)

# %%
pipe.score(X_test, y_test)

# %% [markdown]
# ## 9 Save Machine Learning Model to file

# %%
# import pickle
# with open('./models/linear_regression_multiplefeatures', 'wb') as f:
#     pickle.dump(linear_reg, f)

# %%
# # Better for large numpy arrays
# from sklear.externals import joblib
# joblib.dump(linear_reg, './models/linear_regression_multiplefeatures')

# %% [markdown]
# ### 9.1Load model

# %%
# with open('./models/linear_regression_multiplefeatures', 'rb') as f:
#     model = pickle.load(f)

# %%
# clf = joblib.load('./models/linear_regression_multiplefeatures')

# %% [markdown]
# ### 9.2 Prediction

# %%
# model.predict(X_test)
